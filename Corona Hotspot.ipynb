# %%
import pandas as pd
import folium

# %%
dataset = pd.read_excel("Covid red orange green zones.xlsx")

# %%
dataset.head(20)
# Out:
#     Sr. No.                        State                  District   Latitude  \
# 0         1  Andaman And Nicobar Islands            South Andamans  11.831168
# 1         2  Andaman And Nicobar Islands                  Nicobars  10.387144
# 2         3  Andaman And Nicobar Islands  North And Middle Andaman  12.651883
# 3         4               Andhra Pradesh                   Kurnool  15.828126
# 4         5               Andhra Pradesh                    Guntur  16.306652
# 5         6               Andhra Pradesh                   Krishna  16.610000
# 6         7               Andhra Pradesh                  Chittoor  13.478791
# 7         8               Andhra Pradesh              Spsr Nellore  14.458460
# 8         9               Andhra Pradesh             West Godavari  16.917418
# 9        10               Andhra Pradesh                    Y.S.R.  14.576700
# 10       11               Andhra Pradesh                 Anantapur  14.681888
# 11       12               Andhra Pradesh                  Prakasam  15.348463
# 12       13               Andhra Pradesh             East Godavari  17.321250
# 13       14               Andhra Pradesh                Srikakulam  18.294916
# 14       15               Andhra Pradesh            Visakhapatanam  17.686816
# 15       16               Andhra Pradesh              Vizianagaram  18.106658
# 16       17            Arunachal Pradesh                     Lohit  27.903965
# 17       18            Arunachal Pradesh                 Changlang  27.742176
# 18       19            Arunachal Pradesh             Dibang Valley  28.812877
# 19       20            Arunachal Pradesh               East Kameng  27.423126
#
#    Longitude   greenzone   orangezone   redzone
# 0    92.6586         NaN          NaN  Red Zone
# 1    84.1353  Green Zone          NaN       NaN
# 2    92.8976  Green Zone          NaN       NaN
# 3    78.0373         NaN          NaN  Red Zone
# 4    80.4365         NaN          NaN  Red Zone
# 5    80.7214         NaN          NaN  Red Zone
# 6    78.8383         NaN          NaN  Red Zone
# 7    79.9923         NaN          NaN  Red Zone
# 8    81.3399         NaN  Orange Zone       NaN
# 9    78.8383         NaN  Orange Zone       NaN
# 10   77.6006         NaN  Orange Zone       NaN
# 11   79.5603         NaN  Orange Zone       NaN
# 12   82.0407         NaN  Orange Zone       NaN
# 13   83.8938         NaN  Orange Zone       NaN
# 14   83.2185         NaN  Orange Zone       NaN
# 15   83.3956  Green Zone          NaN       NaN
# 16   96.1739  Green Zone          NaN       NaN
# 17   96.6424  Green Zone          NaN       NaN
# 18   96.1527  Green Zone          NaN       NaN
# 19   93.0176  Green Zone          NaN       NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 733 entries, 0 to 732
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sr. No.     733 non-null    int64
#  1   State       733 non-null    object
#  2   District    733 non-null    object
#  3   Latitude    733 non-null    float64
#  4   Longitude   733 non-null    object
#  5   greenzone   319 non-null    object
#  6   orangezone  283 non-null    object
#  7   redzone     131 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 45.9+ KB

# %%
dataset.columns
# Out:
# Index(['Sr. No.', 'State', 'District', 'Latitude', 'Longitude', 'greenzone',
#        'orangezone', 'redzone'],
#       dtype='object')

# %%
dir = dataset[ ['Latitude', 'Longitude'] ]

# %%
dir = dir.values.tolist()

# %%
type(dir)
# Out:
# list

# %%
name = dataset["District"]

# %%
zones = dataset[['greenzone', 'orangezone', 'redzone']]

# %%
zones = pd.get_dummies(zones )

# %%
zones.columns
# Out:
# Index(['greenzone_Green Zone', 'orangezone_Orange Zone', 'redzone_Red Zone'], dtype='object')

# %%
zones = zones.drop('greenzone_Green Zone' , axis = 1)

# %%
zones.head(15)
# Out:
#     orangezone_Orange Zone  redzone_Red Zone
# 0                        0                 1
# 1                        0                 0
# 2                        0                 0
# 3                        0                 1
# 4                        0                 1
# 5                        0                 1
# 6                        0                 1
# 7                        0                 1
# 8                        1                 0
# 9                        1                 0
# 10                       1                 0
# 11                       1                 0
# 12                       1                 0
# 13                       1                 0
# 14                       1                 0

# %%
zones = zones.values.tolist()

# %%
type(zones)
# Out:
# list

# %%
map = folium.Map(location=[15.828126 , 78.037279] , zoom_start=1)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#marker
def dis(i,color):
    folium.Marker(
        location = point,
        popup = dataset['District'][i],
        icon = folium.Icon(color = color, icon = 'tint', icon_color = 'white')
    ).add_to(map)

# %%
i = 0 
for point in dir:
    if zones[i][0] == 1:
        dis(i , 'orange')
    elif zones[i][1] == 1:
        dis(i , 'darkred')      
    else:
        dis(i , 'green')
    i+=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      58         try:
# ---> 59             float(coord)
#      60         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '76.9552119,'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-b459dc2fb4b0> in <module>
#       4         dis(i , 'orange')
#       5     elif zones[i][1] == 1:
# ----> 6         dis(i , 'darkred')
#       7     else:
#       8         dis(i , 'green')
#
# <ipython-input-19-e4b2ee2795ea> in dis(i, color)
#       4         location = point,
#       5         popup = dataset['District'][i],
# ----> 6         icon = folium.Icon(color = color, icon = 'tint', icon_color = 'white')
#       7     ).add_to(map)
#
# ~\anaconda3\lib\site-packages\folium\map.py in __init__(self, location, popup, tooltip, icon, draggable, **kwargs)
#     275         super(Marker, self).__init__()
#     276         self._name = 'Marker'
# --> 277         self.location = validate_location(location)
#     278         self.options = parse_options(
#     279             draggable=draggable or None,
#
# ~\anaconda3\lib\site-packages\folium\utilities.py in validate_location(location)
#      61             raise ValueError('Location should consist of two numerical values, '
#      62                              'but {!r} of type {} is not convertible to float.'
# ---> 63                              .format(coord, type(coord)))
#      64         if math.isnan(float(coord)):
#      65             raise ValueError('Location values cannot contain NaNs.')
#
# ValueError: Location should consist of two numerical values, but '76.9552119,' of type <class 'str'> is not convertible to float.

# %%
map

# %%
#fill
def dis(i , color):
    folium.LinearColormap(
        location = point,
        popup = dataset['District'][i],
        fill = True,
        fill_color = color,
        
    ).add_to(map)

# %%
i = 0
for point in dir:
    if zones[i][0] == 1:
        dis(i , 'orange')
    elif zones[i][1] == 1:
        dis(i , 'darkred')
    else:
        dis(i , 'green')
    i+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5022840cee76> in <module>
#       4         dis(i , 'orange')
#       5     elif zones[i][1] == 1:
# ----> 6         dis(i , 'darkred')
#       7     else:
#       8         dis(i , 'green')
#
# <ipython-input-21-338e743150b3> in dis(i, color)
#       5         popup = dataset['District'][i],
#       6         fill = True,
# ----> 7         fill_color = color,
#       8
#       9     ).add_to(map)
#
# TypeError: __init__() got an unexpected keyword argument 'location'

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
